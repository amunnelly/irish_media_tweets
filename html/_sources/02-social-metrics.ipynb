# %% [markdown]
# # Social Metrics

# %%
import json
import glob
import pandas as pd
import altair as alt
import pprint

# %%
files = glob.glob("tweets/newspapers/recent_tweets/*.json")
holder = []
for f in files:
    with open(f) as g:
        tweets = json.load(g)
        for item in tweets:
            for t in item['data']:
                temp = {"id": t["id"],
                    "account": f.split("/")[-1][:-5],
                        "created_at": t["created_at"],
                           "likes": t['public_metrics']["like_count"],
                            "quotes": t['public_metrics']["quote_count"],
                            "replies": t['public_metrics']["reply_count"],
                            "retweets": t['public_metrics']["retweet_count"],
                            "reply_settings": t['reply_settings'],
                            "source": t['source'],
                            "text": t['text']}
                holder.append(temp)

# %%
tweets = pd.DataFrame(holder)
tweets['created_at'] = pd.to_datetime(tweets['created_at'])
tweets.index = tweets['id']
del(tweets['id'])
print(tweets.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1995 entries, 1523076460780556288 to 1520623310442143744
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account         1995 non-null   object
#  1   created_at      1995 non-null   datetime64[ns, UTC]
#  2   likes           1995 non-null   int64
#  3   quotes          1995 non-null   int64
#  4   replies         1995 non-null   int64
#  5   retweets        1995 non-null   int64
#  6   reply_settings  1995 non-null   object
#  7   source          1995 non-null   object
#  8   text            1995 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(4), object(4)
# memory usage: 155.9+ KB
# None

# %%
def tweet_finder(data, key, value, account):
    sieve = data[data[key]==value]
    holder = []
    with open(f'tweets/newspapers/recent_tweets/{account}.json') as f:
        temp = json.load(f)
    for item in temp:
        for t in item['data']:
            if t['id'] in sieve.index:
                holder.append(t)
    print(f'The result set has {len(holder)} tweets.')
    return holder

# %% [markdown]
# ## Retweets, Quote Tweets, Likes and Replies

# %%
grouper = tweets.groupby('account')
holder = []
for a, b in grouper:
    temp = b[['likes', 'quotes', 'replies', 'retweets']].copy()
    temp['account'] = a
    holder.append(temp)

# %%
metrics = pd.concat(holder)
z=metrics.describe()
z.style.format(precision=0, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a173">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a173_level0_col0" class="col_heading level0 col0" >likes</th>
#       <th id="T_6a173_level0_col1" class="col_heading level0 col1" >quotes</th>
#       <th id="T_6a173_level0_col2" class="col_heading level0 col2" >replies</th>
#       <th id="T_6a173_level0_col3" class="col_heading level0 col3" >retweets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a173_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6a173_row0_col0" class="data row0 col0" >1,995</td>
#       <td id="T_6a173_row0_col1" class="data row0 col1" >1,995</td>
#       <td id="T_6a173_row0_col2" class="data row0 col2" >1,995</td>
#       <td id="T_6a173_row0_col3" class="data row0 col3" >1,995</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_6a173_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_6a173_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_6a173_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_6a173_row1_col3" class="data row1 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_6a173_row2_col0" class="data row2 col0" >114</td>
#       <td id="T_6a173_row2_col1" class="data row2 col1" >12</td>
#       <td id="T_6a173_row2_col2" class="data row2 col2" >36</td>
#       <td id="T_6a173_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_6a173_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_6a173_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_6a173_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_6a173_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_6a173_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_6a173_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_6a173_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6a173_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_6a173_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_6a173_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_6a173_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_6a173_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_6a173_row6_col0" class="data row6 col0" >9</td>
#       <td id="T_6a173_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_6a173_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_6a173_row6_col3" class="data row6 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6a173_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_6a173_row7_col0" class="data row7 col0" >3,825</td>
#       <td id="T_6a173_row7_col1" class="data row7 col1" >403</td>
#       <td id="T_6a173_row7_col2" class="data row7 col2" >1,214</td>
#       <td id="T_6a173_row7_col3" class="data row7 col3" >786</td>
#     </tr>
#   </tbody>
# </table>

# %%
grouper = tweets.groupby('account')
holder = []
for a, b in grouper:
    temp = pd.DataFrame(b[['likes', 'quotes', 'replies', 'retweets']].unstack())
    temp.reset_index(inplace=True)
    temp['account'] = a
    holder.append(temp)

# %%
chart_metrics = pd.concat(holder)

chart_metrics.rename(columns={0:"value", "level_0":"metric"}, inplace=True)
del(chart_metrics['id'])
chart_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7980 entries, 0 to 1099
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   metric   7980 non-null   object
#  1   value    7980 non-null   int64
#  2   account  7980 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 249.4+ KB

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
metrics_boxplot = alt.Chart(
    chart_metrics).mark_boxplot(
).encode(x=alt.X('account:N', axis=alt.Axis(title="")),
         y=alt.Y('value:Q', axis=alt.Axis(title="count of metric")),
         tooltip=["account",
                  "metric",
                  "value"]).properties(
    width=200,
    title="Public Metrics").facet(
    'metric:N', columns=2)

metrics_boxplot
# Out:
# alt.FacetChart(...)

# %%
tweets[tweets.likes==tweets.likes.max()]
# Out:
#                      account                created_at  likes  quotes  \
# id
# 1522223815044050944  rtenews 2022-05-05 14:36:53+00:00   3825     403
#
#                      replies  retweets reply_settings                source  \
# id
# 1522223815044050944      824       786       everyone  Twitter Media Studio
#
#                                                                   text
# id
# 1522223815044050944  President Michael D Higgins has described the ...

# %% [markdown]
# ## Most Liked Tweet
#
# RTÉ have the most liked tweet of the bunch with 3,825 likes. What was the tweet about?

# %%
print(tweets.loc["1522223815044050944"]['text'])
print(tweets.loc["1522223815044050944"]['created_at'].strftime("%B %d, %H:%M"))
# Out:
# President Michael D Higgins has described the purchase of Twitter by tech billionaire Elon Musk as a 'manifestation of an incredible and dangerous narcissism' | Read more: https://t.co/UcW55R2V7G https://t.co/5b9CZCjL3E
# May 05, 14:36

# %% [markdown]
# The next-most liked tweet is from the Independent:

# %%
tweets[(tweets.account=='independent_ie')&(tweets.likes==2603)]
# Out:
#                             account                created_at  likes  quotes  \
# id
# 1521055649748160512  independent_ie 2022-05-02 09:15:01+00:00   2603      83
#
#                      replies  retweets reply_settings  source  \
# id
# 1521055649748160512      341       307       everyone  Buffer
#
#                                                                   text
# id
# 1521055649748160512  A Catholic couple say they will go to jail rat...

# %%
print(tweets.loc["1521055649748160512"]['text'])
print(tweets.loc["1521055649748160512"]['created_at'].strftime("%B %d, %H:%M"))
# Out:
# A Catholic couple say they will go to jail rather than pay a €300 fine for travelling 70km to attend Mass during lockdown https://t.co/Msgt6bUEUL
# May 02, 09:15

# %% [markdown]
# ## Most Replies
#
# The tweet with the most replies is also from the Independent:

# %%
tweets[(tweets.account=='independent_ie')&(tweets.replies==1214)]
# Out:
#                             account                created_at  likes  quotes  \
# id
# 1522224352930013185  independent_ie 2022-05-05 14:39:01+00:00   1513     297
#
#                      replies  retweets reply_settings  source  \
# id
# 1522224352930013185     1214        31       everyone  Buffer
#
#                                                                   text
# id
# 1522224352930013185  ‘We are pregnant!’- Brian Dowling and partner ...

# %%
print(tweets.loc["1522224352930013185"]['text'])
print(tweets.loc["1522224352930013185"]['created_at'].strftime("%B %d, %H:%M"))
# Out:
# ‘We are pregnant!’- Brian Dowling and partner Arthur Gourounlian announce they’re expecting their first child. https://t.co/RV6q7AOEw6
# May 05, 14:39

# %% [markdown]
# ## Most Retweets
#
# The tweet with the most likes is also the tweet with the most retweets - RTÉ's tweet about the President's remarks on Elon Musk's purchase of Twitter.

# %%
tweets[(tweets.account=='rtenews')&(tweets.retweets==786)]
# Out:
#                      account                created_at  likes  quotes  \
# id
# 1522223815044050944  rtenews 2022-05-05 14:36:53+00:00   3825     403
#
#                      replies  retweets reply_settings                source  \
# id
# 1522223815044050944      824       786       everyone  Twitter Media Studio
#
#                                                                   text
# id
# 1522223815044050944  President Michael D Higgins has described the ...

# %%
print(tweets.loc["1522223815044050944"]['text'])
print(tweets.loc["1522223815044050944"]['created_at'].strftime("%B %d, %H:%M"))
# Out:
# President Michael D Higgins has described the purchase of Twitter by tech billionaire Elon Musk as a 'manifestation of an incredible and dangerous narcissism' | Read more: https://t.co/UcW55R2V7G https://t.co/5b9CZCjL3E
# May 05, 14:36
